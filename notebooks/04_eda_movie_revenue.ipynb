# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import pandas as pd

# Load dataset
df = pd.read_csv('../data/tmdb_movie_dataset.csv')

# Display first 5 rows for a sanity check:
df.head()
# Out:
#             title      genre            director  production_company  \
# 0   The Adventure    Fantasy       David Fincher                 MGM
# 1       A Journey   Thriller     Martin Scorsese  Universal Pictures
# 2      The Secret  Animation        Greta Gerwig          DreamWorks
# 3  The Storm Fire     Comedy        Greta Gerwig                 MGM
# 4  The Past Storm   Thriller  Unknown Director C       Sony Pictures
#
#   release_date     budget  runtime mpaa_rating  trailer_views  trailer_likes  \
# 0   2017-07-20  198606381       93           R       35169902         940628
# 1   2017-05-17   30867257       98       PG-13       28512208         374500
# 2   2023-10-07   61316931       97          PG       10142326         161546
# 3   2022-08-20   98101637      115           G       26661201        1215296
# 4   2018-01-08   60938288      128       PG-13       12712150         351728
#
#    cast_popularity_score  vote_average  vote_count      revenue  release_year  \
# ...

# %%
import pandas as pd

df = pd.read_csv('../data/tmdb_movie_dataset.csv')
df.head()
# Out:
#             title      genre            director  production_company  \
# 0   The Adventure    Fantasy       David Fincher                 MGM
# 1       A Journey   Thriller     Martin Scorsese  Universal Pictures
# 2      The Secret  Animation        Greta Gerwig          DreamWorks
# 3  The Storm Fire     Comedy        Greta Gerwig                 MGM
# 4  The Past Storm   Thriller  Unknown Director C       Sony Pictures
#
#   release_date     budget  runtime mpaa_rating  trailer_views  trailer_likes  \
# 0   2017-07-20  198606381       93           R       35169902         940628
# 1   2017-05-17   30867257       98       PG-13       28512208         374500
# 2   2023-10-07   61316931       97          PG       10142326         161546
# 3   2022-08-20   98101637      115           G       26661201        1215296
# 4   2018-01-08   60938288      128       PG-13       12712150         351728
#
#    cast_popularity_score  vote_average  vote_count      revenue  release_year  \
# ...

# %%
# Shape, column types, nulls
df.shape
# Out:
# (1000, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   title                    1000 non-null   object
#  1   genre                    1000 non-null   object
#  2   director                 1000 non-null   object
#  3   production_company       1000 non-null   object
#  4   release_date             1000 non-null   object
#  5   budget                   1000 non-null   int64
#  6   runtime                  1000 non-null   int64
#  7   mpaa_rating              1000 non-null   object
#  8   trailer_views            1000 non-null   int64
#  9   trailer_likes            1000 non-null   int64
#  10  cast_popularity_score    1000 non-null   float64
#  11  vote_average             1000 non-null   float64
#  12  vote_count               1000 non-null   int64
#  13  revenue                  1000 non-null   int64
# ...

# %%
# Check for missing values
df.isnull().sum()
# Out:
# title                      0
# genre                      0
# director                   0
# production_company         0
# release_date               0
# budget                     0
# runtime                    0
# mpaa_rating                0
# trailer_views              0
# trailer_likes              0
# cast_popularity_score      0
# vote_average               0
# vote_count                 0
# revenue                    0
# release_year               0
# release_month              0
# budget_to_runtime_ratio    0
# trailer_engagement_rate    0
# dtype: int64

# %%
df.describe()
# Out:
#              budget      runtime  trailer_views  trailer_likes  \
# count  1.000000e+03  1000.000000   1.000000e+03   1.000000e+03
# mean   9.970330e+07   126.339000   2.519372e+07   7.605305e+05
# std    6.975173e+07    20.995259   1.452058e+07   5.475698e+05
# min    5.270663e+06    90.000000   1.731320e+05   2.898000e+03
# 25%    4.785914e+07   109.000000   1.257303e+07   3.169252e+05
# 50%    8.299740e+07   127.000000   2.566770e+07   6.549835e+05
# 75%    1.433448e+08   142.000000   3.735107e+07   1.098966e+06
# max    2.981176e+08   180.000000   4.996930e+07   2.389724e+06
#
#        cast_popularity_score  vote_average    vote_count       revenue  \
# count            1000.000000   1000.000000   1000.000000  1.000000e+03
# mean                5.510990      6.470400  48929.885000  6.717998e+09
# std                 2.583145      1.458023  28151.084803  1.106968e+10
# min                 1.010000      4.000000   1037.000000  1.072787e+07
# ...

# %%
df['genre'].value_counts()
# Out:
# genre
# Fantasy      121
# Comedy       112
# Thriller     106
# Romance      106
# Sci-Fi       101
# Adventure     98
# Horror        94
# Drama         93
# Animation     87
# Action        82
# Name: count, dtype: int64

# %%
df['mpaa_rating'].value_counts()
# Out:
# mpaa_rating
# R        296
# PG-13    249
# G        235
# PG       220
# Name: count, dtype: int64

# %%
df['director'].value_counts().head(10)
# Out:
# director
# Martin Scorsese       83
# David Fincher         78
# Unknown Director D    78
# Christopher Nolan     77
# Unknown Director A    77
# Ridley Scott          73
# Steven Spielberg      72
# Unknown Director C    70
# James Cameron         68
# Quentin Tarantino     67
# Name: count, dtype: int64

# %%
# Correlation with revenue
df.corr(numeric_only=True)['revenue'].sort_values(ascending=False)
# Out:
# revenue                    1.000000
# budget                     0.631432
# budget_to_runtime_ratio    0.616262
# trailer_views              0.192604
# vote_average               0.104342
# trailer_likes              0.086644
# cast_popularity_score      0.042500
# runtime                    0.010961
# release_month              0.005339
# release_year              -0.020527
# vote_count                -0.042292
# trailer_engagement_rate   -0.081612
# Name: revenue, dtype: float64

# %%
plt.figure(figsize=(8,4))
sns.histplot(df['revenue'], bins=30, kde=True)
plt.title('Movie Revenue Distribution')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='budget', y='revenue', data=df)
plt.title('Budget vs Revenue')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='genre', y='revenue', data=df)
plt.xticks(rotation=45)
plt.title('Revenue by Genre')
plt.show()

# %%
# Drop columns not useful for modeling (can experiment later)
X = df.drop(['title', 'production_company', 'revenue', 'release_date'], axis=1)
y = df['revenue']

# One-hot encode categorical columns
X_encoded = pd.get_dummies(X, columns=['genre', 'director', 'mpaa_rating'], drop_first=True)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# Model training
reg = LinearRegression()
reg.fit(X_train, y_train)

# Prediction
y_pred = reg.predict(X_test)

# Evaluation metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

print("MAE:", mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R2 Score:", r2)
# Out:
# MAE: 4597082001.981036
# MSE: 5.430604269338313e+19
# RMSE: 7369263375.221646
# R2 Score: 0.5224074003545645

# %%
import matplotlib.pyplot as plt

# Get feature importance from regression coefficients
coef = reg.coef_
features = X_encoded.columns

# Take top 10 most impactful features
top_idx = np.argsort(np.abs(coef))[-10:]
top_features = features[top_idx]
top_values = coef[top_idx]

plt.figure(figsize=(10,5))
plt.barh(top_features, top_values)
plt.xlabel("Coefficient value")
plt.title("Top 10 Feature Importances (Linear Regression)")
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.scatter(y_test, y_pred, alpha=0.5)
plt.xlabel("Actual Revenue")
plt.ylabel("Predicted Revenue")
plt.title("Actual vs Predicted Revenue")
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')  # Line y=x
plt.show()
